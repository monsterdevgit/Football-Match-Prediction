# %%
import requests

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
data = requests.get(standings_url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)

# %%
standings_table = soup.select('table.stats_table')[0]

# %%
links = standings_table.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if '/squads/' in l]

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
data = requests.get(team_urls[0])

# %%
import pandas as pd
matches = pd.read_html(data.text, match="Scores & Fixtures")

# %%
matches =matches[0]

# %%
matches
# Out:
#           Date   Time            Comp         Round  Day Venue Result   GF  \
# 0   2023-08-12  15:00  Premier League   Matchweek 1  Sat  Home      W  4.0
# 1   2023-08-19  15:00  Premier League   Matchweek 2  Sat  Away      W  4.0
# 2   2023-08-26  17:30  Premier League   Matchweek 3  Sat  Home    NaN  NaN
# 3   2023-09-02  17:30  Premier League   Matchweek 4  Sat  Home    NaN  NaN
# 4   2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away    NaN  NaN
# 5   2023-09-24  14:00  Premier League   Matchweek 6  Sun  Home    NaN  NaN
# 6   2023-09-30  12:30  Premier League   Matchweek 7  Sat  Away    NaN  NaN
# 7   2023-10-08  14:00  Premier League   Matchweek 8  Sun  Home    NaN  NaN
# 8   2023-10-21  15:00  Premier League   Matchweek 9  Sat  Away    NaN  NaN
# 9   2023-10-29  14:00  Premier League  Matchweek 10  Sun  Home    NaN  NaN
# 10  2023-11-04    NaN  Premier League  Matchweek 11  Sat  Away    NaN  NaN
# 11  2023-11-11    NaN  Premier League  Matchweek 12  Sat  Home    NaN  NaN
# 12  2023-11-25    NaN  Premier League  Matchweek 13  Sat  Away    NaN  NaN
# 13  2023-12-02    NaN  Premier League  Matchweek 14  Sat  Away    NaN  NaN
# 14  2023-12-05    NaN  Premier League  Matchweek 15  Tue  Home    NaN  NaN
# 15  2023-12-09    NaN  Premier League  Matchweek 16  Sat  Home    NaN  NaN
# 16  2023-12-16    NaN  Premier League  Matchweek 17  Sat  Away    NaN  NaN
# 17  2023-12-23    NaN  Premier League  Matchweek 18  Sat  Away    NaN  NaN
# 18  2023-12-26    NaN  Premier League  Matchweek 19  Tue  Home    NaN  NaN
# 19  2023-12-30    NaN  Premier League  Matchweek 20  Sat  Away    NaN  NaN
# 20  2024-01-13    NaN  Premier League  Matchweek 21  Sat  Home    NaN  NaN
# 21  2024-01-30    NaN  Premier League  Matchweek 22  Tue  Away    NaN  NaN
# 22  2024-02-03    NaN  Premier League  Matchweek 23  Sat  Home    NaN  NaN
# 23  2024-02-10    NaN  Premier League  Matchweek 24  Sat  Away    NaN  NaN
# 24  2024-02-17    NaN  Premier League  Matchweek 25  Sat  Away    NaN  NaN
# 25  2024-02-24    NaN  Premier League  Matchweek 26  Sat  Home    NaN  NaN
# 26  2024-03-02    NaN  Premier League  Matchweek 27  Sat  Away    NaN  NaN
# 27  2024-03-09    NaN  Premier League  Matchweek 28  Sat  Home    NaN  NaN
# 28  2024-03-16    NaN  Premier League  Matchweek 29  Sat  Home    NaN  NaN
# 29  2024-03-30    NaN  Premier League  Matchweek 30  Sat  Away    NaN  NaN
# 30  2024-04-02    NaN  Premier League  Matchweek 31  Tue  Away    NaN  NaN
# 31  2024-04-06    NaN  Premier League  Matchweek 32  Sat  Home    NaN  NaN
# 32  2024-04-13    NaN  Premier League  Matchweek 33  Sat  Away    NaN  NaN
# 33  2024-04-20    NaN  Premier League  Matchweek 34  Sat  Home    NaN  NaN
# 37  NaN   Manchester Utd  NaN  NaN   NaN         NaN         NaN       NaN
#
#         Referee  Match Report  Notes
# 0   David Coote  Match Report    NaN
# 1   Andy Madley  Match Report    NaN
# 2           NaN  Head-to-Head    NaN
# 3           NaN  Head-to-Head    NaN
# 4           NaN  Head-to-Head    NaN
# 5           NaN  Head-to-Head    NaN
# 6           NaN  Head-to-Head    NaN
# 7           NaN  Head-to-Head    NaN
# 8           NaN  Head-to-Head    NaN
# 9           NaN  Head-to-Head    NaN
# 10          NaN  Head-to-Head    NaN
# 11          NaN  Head-to-Head    NaN
# 12          NaN  Head-to-Head    NaN
# 13          NaN  Head-to-Head    NaN
# 14          NaN  Head-to-Head    NaN
# 15          NaN  Head-to-Head    NaN
# 16          NaN  Head-to-Head    NaN
# 17          NaN  Head-to-Head    NaN
# 18          NaN  Head-to-Head    NaN
# 19          NaN  Head-to-Head    NaN
# 20          NaN  Head-to-Head    NaN
# 21          NaN  Head-to-Head    NaN
# 22          NaN  Head-to-Head    NaN
# 23          NaN  Head-to-Head    NaN
# 24          NaN  Head-to-Head    NaN
# 25          NaN  Head-to-Head    NaN
# 26          NaN  Head-to-Head    NaN
# 27          NaN  Head-to-Head    NaN
# 28          NaN  Head-to-Head    NaN
# 29          NaN  Head-to-Head    NaN
# 30          NaN  Head-to-Head    NaN
# 31          NaN  Head-to-Head    NaN
# 32          NaN  Head-to-Head    NaN
# 33          NaN  Head-to-Head    NaN
# 34          NaN  Head-to-Head    NaN
# 35          NaN  Head-to-Head    NaN
# 36          NaN  Head-to-Head    NaN
# 37          NaN  Head-to-Head    NaN

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match="Shooting")[0]
shooting.head()
# Out:
#   For Brighton & Hove Albion                                                 \
#                         Date   Time            Comp        Round  Day Venue
# 0                 2023-08-12  15:00  Premier League  Matchweek 1  Sat  Home
# 1                 2023-08-19  15:00  Premier League  Matchweek 2  Sat  Away
# 2                        NaN    NaN             NaN          NaN  NaN   NaN
#
#                             ... Standard             Expected               \
#   Result GF GA    Opponent  ...     Dist FK PK PKatt       xG npxG npxG/Sh
# 0      W  4  1  Luton Town  ...     17.0  0  1     1      4.0  3.2    0.12
# 1      W  4  1      Wolves  ...     15.6  0  0     0      2.2  2.2    0.14
# 2  2-0-0  8  2         NaN  ...     16.5  0  1     1      6.2  5.4    0.13
#
#                Unnamed: 25_level_0
#   G-xG np:G-xG        Match Report
# 0  0.0    -0.2        Match Report
# 1  1.8     1.8        Match Report
# 2  1.8     1.6                 NaN
#
# [3 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()

# %%
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "G/Sh", "FK", "PK", "PKatt"]], on="Date")
team_data.head()
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 0  2023-08-12  15:00  Premier League  Matchweek 1  Sat  Home      W  4.0  1.0
# 1  2023-08-19  15:00  Premier League  Matchweek 2  Sat  Away      W  4.0  1.0
#
#      Opponent  ...  Formation      Referee  Match Report  Notes  Sh SoT  G/Sh  \
# 0  Luton Town  ...    4-2-3-1  David Coote  Match Report    NaN  26  11  0.12
# 1      Wolves  ...    4-2-3-1  Andy Madley  Match Report    NaN  16   8  0.25
#
#   FK  PK  PKatt
# 0  0   1      1
# 1  0   0      0
#
# [2 rows x 25 columns]

# %%
team_data
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 0  2023-08-12  15:00  Premier League  Matchweek 1  Sat  Home      W  4.0  1.0
# 1  2023-08-19  15:00  Premier League  Matchweek 2  Sat  Away      W  4.0  1.0
#
#      Opponent  ...  Formation      Referee  Match Report  Notes  Sh SoT  G/Sh  \
# 0  Luton Town  ...    4-2-3-1  David Coote  Match Report    NaN  26  11  0.12
# 1      Wolves  ...    4-2-3-1  Andy Madley  Match Report    NaN  16   8  0.25
#
#   FK  PK  PKatt
# 0  0   1      1
# 1  0   0      0
#
# [2 rows x 25 columns]

# %%
years = list(range(2024, 2020, -1))
all_matches = []

# %%
years
# Out:
# [2024, 2023, 2022, 2021]

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "G/Sh", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "Premier League"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)

# %%
len(all_matches)
# Out:
# 80

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2023-08-12  15:00  Premier League   Matchweek 1  Sat  Home      W  4.0
# 1   2023-08-19  15:00  Premier League   Matchweek 2  Sat  Away      W  4.0
# 1   2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W    3
# 3   2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W    1
# 1   2023-08-12  12:30  Premier League   Matchweek 1  Sat  Home      W    2
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 38  2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L    0
# 39  2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L    0
# 40  2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W    1
# 41  2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L    0
# 42  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W    1
#
#      ga         opponent  ...  match report  notes    sh   sot  g/sh   fk  \
# 0   1.0       Luton Town  ...  Match Report    NaN  26.0  11.0  0.12  0.0
# 1   1.0           Wolves  ...  Match Report    NaN  16.0   8.0  0.25  0.0
# 1     0          Burnley  ...  Match Report    NaN  17.0   8.0  0.18  0.0
# 3     0    Newcastle Utd  ...  Match Report    NaN  14.0   4.0  0.07  0.0
# 1     1  Nott'ham Forest  ...  Match Report    NaN  15.0   7.0  0.13  0.0
# ..  ...              ...  ...           ...    ...   ...   ...   ...  ...
# 38    4        Tottenham  ...  Match Report    NaN   8.0   1.0  0.00  0.0
# 39    2   Crystal Palace  ...  Match Report    NaN   7.0   0.0  0.00  1.0
# 40    0          Everton  ...  Match Report    NaN  10.0   3.0  0.10  0.0
# 41    1    Newcastle Utd  ...  Match Report    NaN  11.0   1.0  0.00  1.0
# 42    0          Burnley  ...  Match Report    NaN  12.0   3.0  0.08  0.0
#
#      pk pkatt season                      team
# 0   1.0   1.0   2024  Brighton and Hove Albion
# 1   0.0   0.0   2024  Brighton and Hove Albion
# 1   0.0   0.0   2024           Manchester City
# 3   0.0   0.0   2024           Manchester City
# 1   0.0   0.0   2024                   Arsenal
# ..  ...   ...    ...                       ...
# 38  0.0   0.0   2021          Sheffield United
# 39  0.0   0.0   2021          Sheffield United
# 40  0.0   0.0   2021          Sheffield United
# 41  0.0   0.0   2021          Sheffield United
# 42  0.0   0.0   2021          Sheffield United
#
# [2320 rows x 27 columns]

# %%
match_df.to_csv("matches.csv")
